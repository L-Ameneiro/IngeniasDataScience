# %%
# importamos panda y numpy
import pandas as pd
import numpy as np

# %%
# %pwd
# Out:
# 'd:\\Luna\\Documents\\Repositorios\\IngeniasDataScience\\notebooks'

# %%
cast = pd.read_csv('../datasets/premiados/df_castData.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 cast = pd.read_csv('../datasets/premiados/df_castData.csv')
#
# File c:\Users\Luna\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %%
# importamos panda y numpy
import pandas as pd
import numpy as np

# %%
dat1 = pd.read_csv('../datasets/premiados/the_oscar_award.csv')

# %%
dat1.head(5)
# Out:
#    year_film  year_ceremony  ceremony category                 name  \
# 0       1927           1928         1    ACTOR  Richard Barthelmess
# 1       1927           1928         1    ACTOR        Emil Jannings
# 2       1927           1928         1  ACTRESS       Louise Dresser
# 3       1927           1928         1  ACTRESS         Janet Gaynor
# 4       1927           1928         1  ACTRESS       Gloria Swanson
#
#                film  winner
# 0         The Noose   False
# 1  The Last Command    True
# 2   A Ship Comes In   False
# 3        7th Heaven    True
# 4    Sadie Thompson   False

# %%
dat1.shape
# Out:
# (10765, 7)

# %%
dat2 = dat1[dat1['category'] == 'ACTOR']
dat2.shape
# Out:
# (232, 7)

# %%
dat3 = dat2[dat2['winner'] == True]
dat3.shape
# Out:
# (49, 7)

# %%
dat3.head(4)
# Out:
#      year_film  year_ceremony  ceremony category              name  \
# 1         1927           1928         1    ACTOR     Emil Jannings
# 36        1928           1929         2    ACTOR     Warner Baxter
# 73        1929           1930         3    ACTOR     George Arliss
# 115       1930           1931         4    ACTOR  Lionel Barrymore
#
#                  film  winner
# 1    The Last Command    True
# 36     In Old Arizona    True
# 73           Disraeli    True
# 115       A Free Soul    True

# %%
# Sample data (replace this with your actual DataFrames)
movies_data = {'Movie': ['Movie1', 'Movie2', 'Movie3'],
               'Cast': ['Actor1, Actor2, Actor3', 'Actor4, Actor5', 'Actor6']}
award_winners_data = {'Actor': ['Actor2', 'Actor4']}

movies = pd.DataFrame(movies_data)
award_winners = pd.DataFrame(award_winners_data)

# Create a set of award-winning actors for efficient membership checking
ganador_oscar = set(dat3['name'])

# Create a new column 'IsAwardWinner' in the 'movies' DataFrame
pelis['elenco_oscar'] = movies['elenco'].apply(lambda x: any(names in ganador_oscar for names in x.split(', ')))

# Convert the boolean values to 1 and 0
pelis['elenco_oscar'] = pelis['elenco_oscar'].astype(int)

# %%
pelis=pd.read_csv(r'..\\datasets\\peliculas2.csv')
pelis.head(5)
# Out:
#   show_id   tipo                titulo       director  \
# 0      s2  Movie  Take Care Good Night   Girish Joshi
# 1     s17  Movie              Zoombies   Glenn Miller
# 2     s20  Movie                   Zoe  Drake Doremus
# 3     s23  Movie          Zis Boom Bah   William Nigh
# 4     s25  Movie              Zandalee  Sam Pillsbury
#
#                                               elenco  anio clasificacion  \
# 0   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar  2018           13+
# 1         Marcus Anderson, Kaiwi Lyman, Andrew Asper  2016           13+
# 2  Ewan McGregor, Léa Seydoux, Theo James, Mirand...  2018             R
# 3                            Grace Hayes, Mary Healy  1941            NR
# 4  Nicolas Cage, Judge Reinhold, Erika Anderson, ...  1991             R
#
#   duracion                                       listado_en plataforma
# 0  110 min                             Drama, International     amazon
# ...

# %%
# Create a set of award-winning actors for efficient membership checking
ganador_oscar = set(dat3['name'])

# Create a new column 'IsAwardWinner' in the 'movies' DataFrame
pelis['elenco_oscar'] = pelis['elenco'].apply(lambda x: any(names in ganador_oscar for names in x.split(', ')))

# Convert the boolean values to 1 and 0
pelis['elenco_oscar'] = pelis['elenco_oscar'].astype(int)

# %%
pelis.head(5).sort_values(by='elenco_oscar', ascending = False)
# Out:
#   show_id   tipo                titulo       director  \
# 0      s2  Movie  Take Care Good Night   Girish Joshi
# 1     s17  Movie              Zoombies   Glenn Miller
# 2     s20  Movie                   Zoe  Drake Doremus
# 3     s23  Movie          Zis Boom Bah   William Nigh
# 4     s25  Movie              Zandalee  Sam Pillsbury
#
#                                               elenco  anio clasificacion  \
# 0   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar  2018           13+
# 1         Marcus Anderson, Kaiwi Lyman, Andrew Asper  2016           13+
# 2  Ewan McGregor, Léa Seydoux, Theo James, Mirand...  2018             R
# 3                            Grace Hayes, Mary Healy  1941            NR
# 4  Nicolas Cage, Judge Reinhold, Erika Anderson, ...  1991             R
#
#   duracion                                       listado_en plataforma  \
# 0  110 min                             Drama, International     amazon
# ...

# %%
dir1 = dat1[dat1['category'] == 'DIRECTING']
dir1.shape
# Out:
# (464, 7)

# %%
dir2 = dir1[dir1['winner'] == True]
dir2.shape
# Out:
# (94, 7)

# %%
# Create a set of award-winning actors for efficient membership checking
director_oscar_lista = set(dir1['name'])

# Create a new column 'elenco_oscar' in the 'pelis' DataFrame
pelis['dir_oscar'] = pelis['director'].apply(lambda x: x in director_oscar_lista)

# Convert the boolean values to 1 and 0
pelis['dir_oscar'] = pelis['dir_oscar'].astype(int)

# %%
pelis.head(5).sort_values(by='dir_oscar', ascending = True)
# Out:
#   show_id   tipo                titulo       director  \
# 0      s2  Movie  Take Care Good Night   Girish Joshi
# 1     s17  Movie              Zoombies   Glenn Miller
# 2     s20  Movie                   Zoe  Drake Doremus
# 3     s23  Movie          Zis Boom Bah   William Nigh
# 4     s25  Movie              Zandalee  Sam Pillsbury
#
#                                               elenco  anio clasificacion  \
# 0   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar  2018           13+
# 1         Marcus Anderson, Kaiwi Lyman, Andrew Asper  2016           13+
# 2  Ewan McGregor, Léa Seydoux, Theo James, Mirand...  2018             R
# 3                            Grace Hayes, Mary Healy  1941            NR
# 4  Nicolas Cage, Judge Reinhold, Erika Anderson, ...  1991             R
#
#   duracion                                       listado_en plataforma  \
# 0  110 min                             Drama, International     amazon
# ...

# %%
gg1 = pd.read_csv('../datasets/premiados/golden_globe_awards.csv') 
gg1.head(5)
# Out:
#    year_film  year_award  ceremony  \
# 0       1943        1944         1
# 1       1943        1944         1
# 2       1943        1944         1
# 3       1943        1944         1
# 4       1943        1944         1
#
#                                             category                 nominee  \
# 0  Best Performance by an Actress in a Supporting...          Katina Paxinou
# 1  Best Performance by an Actor in a Supporting R...           Akim Tamiroff
# 2                     Best Director - Motion Picture              Henry King
# 3                                            Picture  The Song Of Bernadette
# 4                          Actress In A Leading Role          Jennifer Jones
#
#                       film   win
# 0  For Whom The Bell Tolls  True
# 1  For Whom The Bell Tolls  True
# 2   The Song Of Bernadette  True
# 3                      NaN  True
# 4   The Song Of Bernadette  True

# %%
gg1.shape
# Out:
# (7991, 7)

# %%
gg_dir1 = gg1[gg1['category'] == 'Best Director - Motion Picture']
gg_dir1.shape
# Out:
# (357, 7)

# %%
# Create a set of award-winning actors for efficient membership checking
director_gg_lista = set(gg_dir1['nominee'])

# Create a new column 'elenco_oscar' in the 'pelis' DataFrame
pelis['dir_gg'] = pelis['director'].apply(lambda x: x in director_gg_lista)

# Convert the boolean values to 1 and 0
pelis['dir_gg'] = pelis['dir_gg'].astype(int)

# %%
pelis.head(5).sort_values(by='dir_gg', ascending = False)
# Out:
#   show_id   tipo                titulo       director  \
# 0      s2  Movie  Take Care Good Night   Girish Joshi
# 1     s17  Movie              Zoombies   Glenn Miller
# 2     s20  Movie                   Zoe  Drake Doremus
# 3     s23  Movie          Zis Boom Bah   William Nigh
# 4     s25  Movie              Zandalee  Sam Pillsbury
#
#                                               elenco  anio clasificacion  \
# 0   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar  2018           13+
# 1         Marcus Anderson, Kaiwi Lyman, Andrew Asper  2016           13+
# 2  Ewan McGregor, Léa Seydoux, Theo James, Mirand...  2018             R
# 3                            Grace Hayes, Mary Healy  1941            NR
# 4  Nicolas Cage, Judge Reinhold, Erika Anderson, ...  1991             R
#
#   duracion                                       listado_en plataforma  \
# 0  110 min                             Drama, International     amazon
# ...

# %%
pelis['dire_gg'].mean
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Luna\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\Luna\anaconda3\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Luna\anaconda3\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dire_gg'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
print(pelis[pelis['dir_gg'] == 1])
# Out:
#       show_id   tipo                                        titulo  \
# 66       s153  Movie                          War Comes to America
# 124      s259  Movie                                   True Colors
# 149      s322  Movie                              To Catch a Thief
# 160      s347  Movie                          Thunder Alley (1967)
# 173      s370  Movie                                   These Three
# ...       ...    ...                                           ...
# 12846   s1213  Movie  Star Wars: Attack of the Clones (Episode II)
# 12848   s1216  Movie  Star Wars: Revenge of the Sith (Episode III)
# 12851   s1219  Movie     Star Wars: The Phantom Menace (Episode I)
# 12953   s1340  Movie                            The Sound of Music
# 13008   s1406  Movie                       Who Framed Roger Rabbit
#
#                director                                             elenco  \
# 66          Frank Capra                     Dean Acheson, General Bergeret
# ...

# %%
print("Número de coincidencias:", pelis['dir_gg'].sum())
# Out:
# Número de coincidencias: 393

# %%
# Filtrar el DataFrame para obtener solo las filas donde dir_gg es igual a 1
directores_ganadores = pelis.loc[pelis['dir_gg'] == 1, 'director']

# Imprimir los valores de la columna 'director' para esas filas
print(directores_ganadores)
# Out:
# 66            Frank Capra
# 124          Herbert Ross
# 149      Alfred Hitchcock
# 160          Richard Rush
# 173         William Wyler
#                ...
# 12846        George Lucas
# 12848        George Lucas
# 12851        George Lucas
# 12953         Robert Wise
# 13008     Robert Zemeckis
# Name: director, Length: 393, dtype: object
