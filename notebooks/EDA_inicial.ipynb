# %% [markdown]
# # Análisis Exploratorio y Procesamiento de Datos

# %%
import pandas as pd
import numpy as np

# %%
## chequeamos el working directory
# %pwd
# Out:
# 'd:\\Luna\\Documents\\Repositorios\\IngeniasDataScience\\notebooks'

# %%
# importamos el dataset en una varialbe llamada amazon
amazon = pd.read_csv('..\\datasets\\amazon_prime_titles.csv')
hulu = pd.read_csv('..\\datasets\\hulu_titles.csv')
disney = pd.read_csv('..\\datasets\\disney_plus_titles.csv')
netflix = pd.read_csv('..\\datasets\\netflix_titles.csv')

# %%
## vemos la forma del dataset
forma_amazon = amazon.shape

f"El dataset tiene {forma_amazon[0]} filas y {forma_amazon[1]} columnas"
# Out:
# 'El dataset tiene 9668 filas y 12 columnas'

# %%
## vemos la forma del dataset
forma_hulu = hulu.shape
f"El dataset tiene {forma_hulu[0]} filas y {forma_hulu[1]} columnas"
# Out:
# 'El dataset tiene 3073 filas y 12 columnas'

# %%
forma_disney = disney.shape
f"El dataset tiene {forma_disney[0]} filas y {forma_disney[1]} columnas"
# Out:
# 'El dataset tiene 1450 filas y 12 columnas'

# %%
forma_netflix = netflix.shape
f"El dataset tiene {forma_netflix[0]} filas y {forma_netflix[1]} columnas"
# Out:
# 'El dataset tiene 8807 filas y 12 columnas'

# %%
forma_df = pd.DataFrame({
    'Dataset': ['Amazon', 'Hulu', 'Netflix', 'Disney'],
    'Filas': [amazon.shape[0], hulu.shape[0], netflix.shape[0], disney.shape[0]],
    'Columnas': [amazon.shape[1], hulu.shape[1], netflix.shape[1], disney.shape[1]]
})

forma_df
# Out:
#    Dataset  Filas  Columnas
# 0   Amazon   9668        12
# 1     Hulu   3073        12
# 2  Netflix   8807        12
# 3   Disney   1450        12

# %%
hulu.tail(5)
# Out:
#      show_id     type                           title director  cast  \
# 3068   s3069  TV Show  Star Trek: The Original Series      NaN   NaN
# 3069   s3070  TV Show              Star Trek: Voyager      NaN   NaN
# 3070   s3071  TV Show                       The Fades      NaN   NaN
# 3071   s3072  TV Show               The Twilight Zone      NaN   NaN
# 3072   s3073  TV Show             Tokyo Magnitude 8.0      NaN   NaN
#
#              country date_added  release_year rating   duration  \
# 3068   United States        NaN          1966  TV-PG  3 Seasons
# 3069   United States        NaN          1997  TV-PG  7 Seasons
# 3070  United Kingdom        NaN          2011  TV-14   1 Season
# 3071   United States        NaN          1959  TV-PG  5 Seasons
# 3072           Japan        NaN          2009  TV-14   1 Season
#
#                                    listed_in  \
# 3068             Action, Adventure, Classics
# 3069      Action, Adventure, Science Fiction
# 3070  Horror, International, Science Fiction
# 3071     Classics, Science Fiction, Thriller
# 3072             Anime, Drama, International
#
#                                             description
# 3068  The 23rd century adventures of Captain James T...
# 3069  Catapulted into the distant sector of the gala...
# 3070  Seventeen-year-old Paul is haunted by apocalyp...
# 3071  Rod Serling's seminal anthology series focused...
# 3072  The devastation is unleashed in the span of se...

# %% [markdown]
# ## Exploración de las columnas

# %% [markdown]
# Verificamos que los 4 datasets tengan las mismas columnas

# %%
# vemos los nombres de las columnas
print(amazon.columns)
print(disney.columns)
print(hulu.columns)
print(netflix.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# Creamos una columna que indica la plataforma

# %%
amazon['plataforma'] = "amazon"
hulu['plataforma'] = "hulu"
disney['plataforma'] = "disney"
netflix['plataforma'] = "netflix"

# %% [markdown]
# ## Unir datasets

# %%
df = pd.concat([amazon, hulu, netflix, disney], axis=0, ignore_index=True)

# %%
df.shape
# Out:
# (22998, 13)

# %%
df.tail(5)
# Out:
#       show_id   type                                           title  \
# 22993   s1446  Movie                        X-Men Origins: Wolverine
# 22994   s1447  Movie  Night at the Museum: Battle of the Smithsonian
# 22995   s1448  Movie                                 Eddie the Eagle
# 22996   s1449  Movie                            Bend It Like Beckham
# 22997   s1450  Movie           Captain Sparky vs. The Flying Saucers
#
#               director                                               cast  \
# 22993       Gavin Hood  Hugh Jackman, Liev Schreiber, Danny Huston, wi...
# 22994       Shawn Levy  Ben Stiller, Amy Adams, Owen Wilson, Hank Azar...
# 22995  Dexter Fletcher  Tom Costello, Jo Hartley, Keith Allen, Dickon ...
# 22996  Gurinder Chadha  Parminder Nagra, Keira Knightley, Jonathan Rhy...
# 22997      Mark Waring                                      Charlie Tahan
#
#                                       country          date_added  \
# 22993           United States, United Kingdom        June 4, 2021
# 22994                   United States, Canada       April 2, 2021
# 22995  United Kingdom, Germany, United States   December 18, 2020
# 22996  United Kingdom, Germany, United States  September 18, 2020
# 22997                           United States       April 1, 2020
#
#        release_year rating duration  \
# 22993          2009  PG-13  108 min
# 22994          2009     PG  106 min
# 22995          2016  PG-13  107 min
# 22996          2003  PG-13  112 min
# 22997          2012   TV-G    2 min
#
#                                            listed_in  \
# 22993      Action-Adventure, Family, Science Fiction
# 22994               Action-Adventure, Comedy, Family
# 22995                    Biographical, Comedy, Drama
# 22996                   Buddy, Comedy, Coming of Age
# 22997  Action-Adventure, Animals & Nature, Animation
#
#                                              description plataforma
# 22993  Wolverine unites with legendary X-Men to fight...     disney
# 22994  Larry Daley returns to rescue some old friends...     disney
# 22995  True story of Eddie Edwards, a British ski-jum...     disney
# 22996  Despite the wishes of their traditional famili...     disney
# 22997         View one of Sparky's favorite home movies.     disney

# %% [markdown]
# Renombramos las columnas para que estén en español y sean más intuitivos:

# %%
df.columns = ['show_id', 'tipo', 'titulo', 'director', 'elenco', 
                  'pais', 'fecha_agregado', 'anio', 'clasificacion', 'duracion', 
                 'listado_en', 'descripcion', 'plataforma']

# %%
# chequeamos que los nombres cambiaron
print(df.columns)
# Out:
# Index(['show_id', 'tipo', 'titulo', 'director', 'elenco', 'pais',
#        'fecha_agregado', 'anio', 'clasificacion', 'duracion', 'listado_en',
#        'descripcion', 'plataforma'],
#       dtype='object')

# %%
# vemos las primeras filas del dataset
df.head(10)
# Out:
#   show_id   tipo                 titulo                     director  \
# 0      s1  Movie    The Grand Seduction                 Don McKellar
# 1      s2  Movie   Take Care Good Night                 Girish Joshi
# 2      s3  Movie   Secrets of Deception                  Josh Webber
# 3      s4  Movie     Pink: Staying True               Sonia Anderson
# 4      s5  Movie          Monster Maker                 Giles Foster
# 5      s6  Movie  Living With Dinosaurs                 Paul Weiland
# 6      s7  Movie              Hired Gun                  Fran Strine
# 7      s8  Movie           Grease Live!  Thomas Kail, Alex Rudzinski
# 8      s9  Movie        Global Meltdown                Daniel Gilboy
# 9     s10  Movie         David's Mother        Robert Allan Ackerman
#
#                                               elenco            pais  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3  Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4  Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# 5  Gregory Chisholm, Juliet Stevenson, Brian Hens...  United Kingdom
# 6  Alice Cooper, Liberty DeVitto, Ray Parker Jr.,...   United States
# 7  Julianne Hough, Aaron Tveit, Vanessa Hudgens, ...   United States
# 8  Michael Paré, Leanne Khol Young, Patrick J. Ma...          Canada
# 9    Kirstie Alley, Sam Waterston, Stockard Channing   United States
#
#    fecha_agregado  anio clasificacion duracion  \
# 0  March 30, 2021  2014           NaN  113 min
# 1  March 30, 2021  2018           13+  110 min
# 2  March 30, 2021  2017           NaN   74 min
# 3  March 30, 2021  2014           NaN   69 min
# 4  March 30, 2021  1989           NaN   45 min
# 5  March 30, 2021  1989           NaN   52 min
# 6  March 30, 2021  2017           NaN   98 min
# 7  March 30, 2021  2016           NaN  131 min
# 8  March 30, 2021  2017           NaN   87 min
# 9   April 1, 2021  1994           NaN   92 min
#
#                           listado_en  \
# 0                      Comedy, Drama
# 1               Drama, International
# 2            Action, Drama, Suspense
# 3                        Documentary
# 4                     Drama, Fantasy
# 5                      Fantasy, Kids
# 6      Documentary, Special Interest
# 7                             Comedy
# 8  Action, Science Fiction, Suspense
# 9                              Drama
#
#                                          descripcion plataforma
# 0  A small fishing village must procure a local d...     amazon
# 1  A Metro Family decides to fight a Cyber Crimin...     amazon
# 2  After a man discovers his wife is cheating on ...     amazon
# 3  Pink breaks the mold once again, bringing her ...     amazon
# 4  Teenage Matt Banting wants to work with a famo...     amazon
# 5  The story unfolds in a an English seaside town...     amazon
# 6  They are the "First Call, A-list" musicians, j...     amazon
# 7  This honest, uncompromising comedy chronicles ...     amazon
# 8  A helicopter pilot and an environmental scient...     amazon
# 9  Sally Goodson is a devoted mother to her autis...     amazon

# %% [markdown]
# ### Las columnas contienen los siguientes datos:
# - **show_id:** identificador único de cada serie o película
# - **tipo:** indica si se trata de una serie ("TV Show") o de una película ("Movie")
# - **titulo**
# - **director**
# - **elenco:** lista separada por comas de los nombres del elenco
# - **pais:** país de producción
# - **fecha_agregado:** fecha en que se agregó a la plataforma
# - **anio:** año de producción
# - **calificacion:** edad mínima o público recomendado
# - **duracion:** duración en minutos para películas, en temporadas para series </br>
#         - *Procesamiento necesario:* eliminar las palabras "min"/"season" y convertir a integer
# - **listado_en:** géneros en los cuales aparece listada la serie o película en la plataforma. </br>
#        - *Procesamiento necesario:* Valores separados por comas, hay que separar en columnas tipo dummies. Cada producto aparece listado en al menos una categoría/género, pero la cantidad total es variable.
# - **descripcion:** una descripción en inglés de la trama de la serie o película

# %% [markdown]
# ### ¿Cuántas películas y cuántas series hay en la plataforma?

# %%
# Contar la cantidad de filas por tipo
contar_tipo = df['tipo'].value_counts()
print(f"Hay {contar_tipo[0]} películas y {contar_tipo[1]} series")
# Out:
# Hay 16481 películas y 6517 series

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 import seaborn as sns
#
# ModuleNotFoundError: No module named 'seaborn'

# %% [markdown]
# ### Filtramos para quedarnos sólo las películas

# %%
# Armo un nuevo dataframe filtrando por el valor de la columna tipo
df = df[df['tipo'] == "Movie"]
df.shape ## chequeo la cantidad de filas
# Out:
# (16481, 13)

# %% [markdown]
# ## Análisis de datos faltantes

# %%
# Vemos cuántos valores faltantes tiene cada columna:
missing_values = df.isnull().sum().sort_values(ascending = False) # contabiliza
        # datos faltantes y los ordena de mayor a menor
        # según la columna
missing_values
# Out:
# pais              8614
# fecha_agregado    7798
# elenco            2842
# director          1973
# clasificacion      624
# duracion           482
# descripcion          3
# show_id              0
# tipo                 0
# titulo               0
# anio                 0
# listado_en           0
# plataforma           0
# dtype: int64

# %%
# visualización de valores faltantes
plt.figure(figsize=(10, 6))
sns.heatmap(df.isnull(), cmap='viridis', cbar=False)
plt.title('Valores Faltantes en el DataFrame')
plt.show()

# %% [markdown]
# Vemos que la columna fecha_agregada son casi todos datos faltantes. Lo mismo pasa con la columna país. Estos no van a ser elementos útiles para la recomendación. </br>
# Las columnas más importantes para el sistema de recomendación (título, descripcion, calificacion, elenco, listado_en) no tienen datos faltantes, asíque podemos trabajar con ellas sin problema.

# %% [markdown]
# ## Columna clasificación

# %%
# Contamos la cantidad de filas para cada clasificacion
contar_clas = df['clasificacion'].value_counts()
print(contar_clas)
# Out:
# clasificacion
# TV-MA        2154
# R            2152
# 13+          1849
# TV-14        1546
# 16+          1272
#              ...
# 65 min          1
# 37 min          1
# NOT RATED       1
# 129 min         1
# 115 min         1
# Name: count, Length: 104, dtype: int64

# %%
# Contamos la cantidad de filas para cada calificacion
contar_clas_hulu = hulu['rating'].value_counts()
print(contar_clas_hulu)
# Out:
# rating
# TV-14     691
# TV-MA     391
# R         345
# TV-PG     321
# PG-13     163
#          ...
# 34 min      1
# 47 min      1
# 65 min      1
# 37 min      1
# 71 min      1
# Name: count, Length: 88, dtype: int64

# %% [markdown]
# Vemos que hay filas cuya clasificación aparece como cantidad de minutos. Esto indica un error o anomalía en el dataset. Vamos a indagar a qué plataforma corresponden las filas anómalas.

# %%
# queremos ver que valor tiene la columna paltaforma cuando clasificacion contiene "min", "season" o "seasons" (sin distinguir entre masyuscula y minusucula)
# creamos una mascara booleana para encontrar las filas que cumplen con la condicion de contener "min"
# dado que la columna clasificacion tiene valores nulos, vamos a indicar que tome esos valores como falso
mascara = df['clasificacion'].str.contains('min|Season|Seasons', case=False, na=False)

# Aplicar la máscara booleana y obtener los valores de "plataforma"
anomalos = df.loc[mascara, 'plataforma']

# Mostrar los valores de "plataforma" que cumplen con el criterio
print(anomalos)
# Out:
# 9718        hulu
# 9776        hulu
# 9931        hulu
# 10065       hulu
# 10139       hulu
#           ...
# 12627       hulu
# 12661       hulu
# 18282    netflix
# 18535    netflix
# 18554    netflix
# Name: plataforma, Length: 295, dtype: object

# %% [markdown]
# A que plataformas pertenecen estos titulos?

# %%
print(anomalos.unique())
# Out:
# ['hulu' 'netflix']

# %% [markdown]
# Cuantos hay corresponden a Netflix y cuántos en Hulu??

# %%
contar_anomalos = anomalos.value_counts()
print(contar_anomalos)
# Out:
# plataforma
# hulu       292
# netflix      3
# Name: count, dtype: int64

# %% [markdown]
# Vemos que no se trata de un problema que afecte a la mayoría de las películas. Pero dado que la clasificación es un dato de vital imortancia a tener en cuenta en un algoritmo de recomendación y que la recolección de esos datos escapa a los objetivos de este proyecto, tomamos la decisión de eliminar las filas anómalas de los análisis posteriores, así como aquellas filas con valores faltantes en esta columna.

# %%
# descartamos filas con valores faltantes en clasificacion
df2 = df.dropna(subset=['clasificacion'])
df2.shape
# Out:
# (15857, 13)

# %%
# descartamos filas anomalas para clasificacion
filas_anomalas = df2.index[df2['clasificacion'].str.contains('min|Season|Seasons', case=False, na=False)]

# Elimina las filas correspondientes a esos índices del DataFrame original
df2 = df2.drop(filas_anomalas)

# %%
df2.shape
# Out:
# (15562, 13)

# %%
df = df2

# %%
# Contamos la cantidad de filas para cada clasificacion
contar_clas2 = df['clasificacion'].value_counts()
print(contar_clas2)
# Out:
# clasificacion
# TV-MA        2154
# R            2152
# 13+          1849
# TV-14        1546
# 16+          1272
# PG-13        1112
# 18+          1097
# ALL           988
# PG            880
# TV-PG         770
# G             405
# TV-G          395
# 7+            288
# NR            270
# TV-Y7         179
# TV-Y          140
# UNRATED        33
# TV-Y7-FV       12
# NC-17           6
# UR              3
# NOT_RATE        3
# AGES_18_        3
# AGES_16_        2
# NOT RATED       1
# ALL_AGES        1
# 16              1
# Name: count, dtype: int64

# %%
df['clasificacion'] = df['clasificacion'].replace(['UNRATED', 'UR'], 'UR/No clasificado')
df['clasificacion'] = df['clasificacion'].replace(['NOT RATED', 'NOT_RATE', 'NR'], 'NR/Sin clasificacion')
df['clasificacion'] = df['clasificacion'].replace(['ALL', 'ALL_AGES'], 'ALL')
df['clasificacion'] = df['clasificacion'].replace(['AGES_18_'], '18+')
df['clasificacion'] = df['clasificacion'].replace(['16','AGES_16_','16+'], '16+')

# %%
# Contamos la cantidad de filas para cada clasificacion
contar_clas3 = df['clasificacion'].value_counts()
print(contar_clas3)
# Out:
# clasificacion
# TV-MA                2154
# R                    2152
# 13+                  1849
# TV-14                1546
# 16+                  1275
# PG-13                1112
# 18+                  1100
# ALL                   989
# PG                    880
# TV-PG                 770
# G                     405
# TV-G                  395
# 7+                    288
# Sin clasificacion     274
# TV-Y7                 179
# TV-Y                  140
# No clasificado         36
# TV-Y7-FV               12
# NC-17                   6
# Name: count, dtype: int64

# %%
# Crear el gráfico de barras
plt.bar(contar_clas.index, contar_clas.values)
plt.xlabel('Calificación', fontsize=18)
plt.ylabel('Cantidad de títulos', fontsize=18)
plt.title('¿Cuántas películas de cada calificación hay en la plataforma?', fontsize=23)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=18)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Crear el gráfico de barras
plt.bar(contar_clas.index, contar_clas.values)
plt.xlabel('Calificación', fontsize=18)
plt.ylabel('Cantidad de títulos', fontsize=18)
plt.title('¿Cuántas películas de cada calificación hay en la plataforma?', fontsize=23)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=18)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Habría que limpiar los valores de calificación, ya que vemos que las categorías con menor frecuencia son repeticiones de las de mayor frecuencia. </br>
# Pero vamos a seguir adelante.

# %%
# Contar la cantidad de filas 
contar_calif_tv = amazon_tv['calificacion'].value_counts()

# Crear el gráfico de barras
plt.bar(contar_calif_tv.index, contar_calif_tv.values)
plt.xlabel('Calificación', fontsize=18)
plt.ylabel('Cantidad de títulos', fontsize=18)
plt.title('Cuántas series por calificación hay en la plataforma?', fontsize=23)
plt.xticks(rotation=45, fontsize=12)
plt.yticks(fontsize=18)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
# Vamos a guardar los dataframe en archivos CSV
amazon_peli.to_csv('.\\datasets\\amazon_peli.csv', index=False)
amazon_tv.to_csv('.\\datasets\\amazon_tv.csv', index=False)

# %% [markdown]
# ## Columna duracion

# %%
# vemos la columna duracion para las películas
amazon_peli.head(3)
# Out:
#   show_id   tipo                titulo      director  \
# 0      s1  Movie   The Grand Seduction  Don McKellar
# 1      s2  Movie  Take Care Good Night  Girish Joshi
# 2      s3  Movie  Secrets of Deception   Josh Webber
#
#                                               elenco           pais  \
# 0     Brendan Gleeson, Taylor Kitsch, Gordon Pinsent         Canada
# 1   Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar          India
# 2  Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...  United States
#
#    fecha_agregado  anio calificacion duracion               listado_en  \
# 0  March 30, 2021  2014          NaN  113 min            Comedy, Drama
# 1  March 30, 2021  2018          13+  110 min     Drama, International
# 2  March 30, 2021  2017          NaN   74 min  Action, Drama, Suspense
#
#                                          descripcion
# 0  A small fishing village must procure a local d...
# 1  A Metro Family decides to fight a Cyber Crimin...
# 2  After a man discovers his wife is cheating on ...

# %%
# vemos la columna duracion para las series
amazon_tv.head(3)
# Out:
#    show_id     tipo                         titulo director  \
# 17     s18  TV Show                     Zoo Babies      NaN
# 18     s19  TV Show  Zoë Coombs Marr: Bossy Bottom      NaN
# 20     s21  TV Show                     Zoboomafoo      NaN
#
#                         elenco pais fecha_agregado  anio calificacion  \
# 17  Narrator - Gillian Barlett  NaN            NaN  2008          ALL
# 18             Zoë Coombs Marr  NaN            NaN  2020          18+
# 20                         NaN  NaN            NaN  2001         TV-Y
#
#     duracion                     listado_en  \
# 17  1 Season         Kids, Special Interest
# 18  1 Season  Comedy, Talk Show and Variety
# 20  1 Season                           Kids
#
#                                           descripcion
# 17  A heart warming and inspiring series that welc...
# 18  Zoë Coombs Marr has been on hiatus. Sort of. F...
# 20  Chris and Martin Kratt bring their enthusiasm ...

# %% [markdown]
# Vemos que para las películas, la duracion se expresa como cantidad de minutos.  </br>
# Mientras que para las series, se expresa como cantidad de temporadas.
# </br>
# Esto significa que solamente podremos usar esta columna para clasificar por separado series o películas, ya que miden distintas propiedades (minutos y temporadas respectivamente). </br>
# Vamos a procesar los datos de la columna para poder utilizarlos.

# %%
amazon_peli = pd.read_csv('.\\datasets\\amazon_peli.csv')
amazon_tv = pd.read_csv('.\\datasets\\amazon_tv.csv')

# %%
# Quitamos "min" y convertir a integer 
amazon_peli['duracion'] = amazon_peli['duracion'].str.replace(' min', '').astype(int)

# %%
# Ahora con las series
# Obtenemos los valores unicos en la columna duracion para las series 
uniquedur = amazon_tv['duracion'].unique()
print(uniquedur)
# Out:
# ['1' '3s' '2s' '4s' '7s' '9s' '6s' '5s' '29s' '19s' '21s' '8s' '12s' '11s'
#  '10s' '14s' '15s']

# %% [markdown]
# Vemos que hay algunas filas con el formato "numero + season/seasons" y otras con el formato "numero + s". </br>
# Asíque algunas son temporadas y otras segundos. </br>
# Por ahora vamos a reemplazar las que estén en temporadas.

# %%
# Quitamos "Season" y "Seasons"
amazon_tv['duracion'] = amazon_tv['duracion'].str.replace(' Season', '').str.replace(' Seasons', '')

# %% [markdown]
# Aun no podemos convertir a integer porque algunas filas están en segundos y no fueron modificadas, así que al convertir a integer se volverían nulas. </br>
# Por ahora vamos a seguir adelante aunque queda pendiente el procesamiento de esta columna. </br>
# Según cómo querramos utilizar las distintas formas de duración, quizás deberíamos crear distintas columnas para cada forma de medición, y explorar por qué algunos productos se miden en segundos (qué tipo de productos son? nos sirven para el análisis? deberíamos eliminarlos?).

# %% [markdown]
# ### ¿Cuántas series y películas de cada año hay en la plataforma?

# %%
# Agrupar por tipo y anio, y contar la cantidad de filas
contar_anio = amazon.groupby(['anio', 'tipo']).size().unstack()

# Crear un gráfico de barras apiladas con anio en el eje x
plt.figure(figsize=(10, 6))
contar_anio.plot(kind='bar', stacked=True)
plt.xlabel('Año', fontsize = 18)
plt.ylabel('Cantidad de Títulos', fontsize = 18)
plt.title('Series y películas por año', fontsize = 23)
plt.legend(title='Tipo', fontsize = 18)
plt.xticks([]) # eliminar etiquetas de eje x porque queda muy cargado
plt.yticks(fontsize = 18)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Columna listado_en: categorías y géneros

# %%
amazon['listado_en'].head(3)
# Out:
# 0              Comedy, Drama
# 1       Drama, International
# 2    Action, Drama, Suspense
# Name: listado_en, dtype: object

# %% [markdown]
# Vemos que la columna listado_en contiene varios valores separados por comas. Vamos a separar cada valor en una columna para poder utilizarlas para agrupar las filas.

# %%
# Dividir los valores en columnas separadas
generos = amazon['listado_en'].str.split(',', expand=True)
print(generos)
# Out:
#                 0               1          2     3     4
# 0          Comedy           Drama       None  None  None
# 1           Drama   International       None  None  None
# 2          Action           Drama   Suspense  None  None
# 3     Documentary            None       None  None  None
# 4           Drama         Fantasy       None  None  None
# ...           ...             ...        ...   ...   ...
# 9663       Comedy            None       None  None  None
# 9664     TV Shows            None       None  None  None
# 9665       Action            None       None  None  None
# 9666        Drama          Sports       None  None  None
# 9667       Action           Drama   Suspense  None  None
#
# [9668 rows x 5 columns]

# %%
generos.columns = ['gen1', 'gen2', 'gen3', 'gen4', 'gen5']

# %%
print(generos)
# Out:
#              gen1            gen2       gen3  gen4  gen5
# 0          Comedy           Drama       None  None  None
# 1           Drama   International       None  None  None
# 2          Action           Drama   Suspense  None  None
# 3     Documentary            None       None  None  None
# 4           Drama         Fantasy       None  None  None
# ...           ...             ...        ...   ...   ...
# 9663       Comedy            None       None  None  None
# 9664     TV Shows            None       None  None  None
# 9665       Action            None       None  None  None
# 9666        Drama          Sports       None  None  None
# 9667       Action           Drama   Suspense  None  None
#
# [9668 rows x 5 columns]

# %%
# Concatenar las nuevas columnas al DataFrame original
amazon = pd.concat([amazon, generos], axis=1)
print(amazon)
# Out:
#      show_id     tipo                   titulo         director  \
# 0         s1    Movie      The Grand Seduction     Don McKellar
# 1         s2    Movie     Take Care Good Night     Girish Joshi
# 2         s3    Movie     Secrets of Deception      Josh Webber
# 3         s4    Movie       Pink: Staying True   Sonia Anderson
# 4         s5    Movie            Monster Maker     Giles Foster
# ...      ...      ...                      ...              ...
# 9663   s9664    Movie      Pride Of The Bowery  Joseph H. Lewis
# 9664   s9665  TV Show            Planet Patrol              NaN
# 9665   s9666    Movie                  Outpost     Steve Barker
# 9666   s9667  TV Show  Maradona: Blessed Dream              NaN
# 9667   s9668    Movie              Harry Brown    Daniel Barber
#
#                                                  elenco            pais  \
# 0        Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1      Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2     Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3     Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4     Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# ...                                                 ...             ...
# 9663                           Leo Gorcey, Bobby Jordan             NaN
# 9664  DICK VOSBURGH, RONNIE STEVENS, LIBBY MORRIS, M...             NaN
# 9665  Ray Stevenson, Julian Wadham, Richard Brake, M...             NaN
# 9666  Esteban Recagno, Ezequiel Stremiz, Luciano Vit...             NaN
# 9667  Michael Caine, Emily Mortimer, Joseph Gilgun, ...             NaN
#
#       fecha_agregado  anio calificacion   duracion               listado_en  \
# 0     March 30, 2021  2014          NaN    113 min            Comedy, Drama
# 1     March 30, 2021  2018          13+    110 min     Drama, International
# 2     March 30, 2021  2017          NaN     74 min  Action, Drama, Suspense
# 3     March 30, 2021  2014          NaN     69 min              Documentary
# 4     March 30, 2021  1989          NaN     45 min           Drama, Fantasy
# ...              ...   ...          ...        ...                      ...
# 9663             NaN  1940           7+     60 min                   Comedy
# 9664             NaN  2018          13+  4 Seasons                 TV Shows
# 9665             NaN  2008            R     90 min                   Action
# 9666             NaN  2021        TV-MA   1 Season            Drama, Sports
# 9667             NaN  2010            R    103 min  Action, Drama, Suspense
#
#                                             descripcion         gen1  \
# 0     A small fishing village must procure a local d...       Comedy
# 1     A Metro Family decides to fight a Cyber Crimin...        Drama
# 2     After a man discovers his wife is cheating on ...       Action
# 3     Pink breaks the mold once again, bringing her ...  Documentary
# 4     Teenage Matt Banting wants to work with a famo...        Drama
# ...                                                 ...          ...
# 9663  New York City street principles get an East Si...       Comedy
# 9664  This is Earth, 2100AD - and these are the adve...     TV Shows
# 9665  In war-torn Eastern Europe, a world-weary grou...       Action
# 9666  The series tells the story of Diego Maradona, ...        Drama
# 9667  Harry Brown, starring two-time Academy Award w...       Action
#
#                 gen2       gen3  gen4  gen5
# 0              Drama       None  None  None
# 1      International       None  None  None
# 2              Drama   Suspense  None  None
# 3               None       None  None  None
# 4            Fantasy       None  None  None
# ...              ...        ...   ...   ...
# 9663            None       None  None  None
# 9664            None       None  None  None
# 9665            None       None  None  None
# 9666          Sports       None  None  None
# 9667           Drama   Suspense  None  None
#
# [9668 rows x 17 columns]

# %% [markdown]
# No pude procesar esta columna de manera que me permita agrupar y graficar por género/categoría. Un camino posible sería crear columnas dummies para cada categoría, tal que cada fila contenga 1 o 0 según corresponda. Pero quizás hay una forma más elegante ya que serían muchas columnas dummies.

# %% [markdown]
# A partir de acá es todo muy exploratorio:

# %%
# Contar la cantidad de filas para cada valor único en gen1
contar_gen1_peli = amazon_peli['gen1'].value_counts()

# Crear el gráfico de barras
plt.bar(contar_gen1_peli.index, contar_gen1_peli.values)
plt.xlabel('Valores en columna A')
plt.ylabel('Cantidad de filas')
plt.title('Distribución de valores en columna A')
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar el gráfico
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gen1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Contar la cantidad de filas para cada valor único en gen1
# ----> 2 contar_gen1_peli = amazon_peli['gen1'].value_counts()
#       4 # Crear el gráfico de barras
#       5 plt.bar(contar_gen1_peli.index, contar_gen1_peli.values)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'gen1'

# %%
# Contar la cantidad de filas para cada valor único en gen1
contar_gen1 = amazon.pel['gen1'].value_counts()

# Crear el gráfico de barras
plt.bar(contar_gen1.index, contar_gen1.values)
plt.xlabel('Valores en columna A')
plt.ylabel('Cantidad de filas')
plt.title('Distribución de valores en columna A')
plt.xticks(rotation=45)
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
amazon_peli.head(50
                )
# Out:
#    show_id   tipo                                             titulo  \
# 0       s1  Movie                                The Grand Seduction
# 1       s2  Movie                               Take Care Good Night
# 2       s3  Movie                               Secrets of Deception
# 3       s4  Movie                                 Pink: Staying True
# 4       s5  Movie                                      Monster Maker
# 5       s6  Movie                              Living With Dinosaurs
# 6       s7  Movie                                          Hired Gun
# 7       s8  Movie                                       Grease Live!
# 8       s9  Movie                                    Global Meltdown
# 9      s10  Movie                                     David's Mother
# 10     s11  Movie                                     Forest Fairies
# 11     s12  Movie                                          Take Care
# 12     s13  Movie                           The Night Eats The World
# 13     s14  Movie                                         Resilencia
# 14     s15  Movie                  Elon Musk: The Real Life Iron Man
# 15     s16  Movie                                         Summer '03
# 16     s17  Movie                                           Zoombies
# 17     s20  Movie                                                Zoe
# 18     s23  Movie                                       Zis Boom Bah
# 19     s25  Movie                                           Zandalee
# 20     s26  Movie                             Zambezi: Force of Life
# 21     s33  Movie                                       Young Lovers
# 22     s34  Movie                    Young Love (at the Sun Factory)
# 23     s35  Movie                    Young Love (at Bowery Ballroom)
# 24     s37  Movie                                     You're Not You
# 25     s38  Movie                                    You, Me and Him
# 26     s39  Movie                        Yoga with Sound Meditations
# 27     s40  Movie                 Yoga to Harness Your Chakra Energy
# 28     s41  Movie                        Yoga to Ease Flight Anxiety
# 29     s42  Movie                            Yoga to Break Any Habit
# 30     s44  Movie                           Yoga Savasana Relaxation
# 31     s45  Movie                       Yoga for Relaxation Anywhere
# 32     s46  Movie     Yoga for Relaxation and Stress Relief Anywhere
# 33     s47  Movie              Yoga for Relaxation and Stress Relief
# 34     s48  Movie                Yoga for Mindfulness and Meditation
# 35     s49  Movie                              Yoga for Men's Health
# 36     s50  Movie                          Yoga for Breath Awareness
# 37     s51  Movie                                 Yoga For Beginners
# 38     s52  Movie                       Yoga for Abdominal Breathing
# 39     s53  Movie                                         Yellowneck
# 40     s55  Movie                                     Yatra (Telugu)
# 41     s56  Movie                                  Yatra (Malayalam)
# 42     s60  Movie                                            Xchange
# 43     s61  Movie                                              X-Ray
# 44     s63  Movie                       Wrangler: Anatomy of an Icon
# 45     s69  Movie                   World War II: Saving the Reality
# 46     s71  Movie                   World Inferno Friendship Society
# 47     s74  Movie                            Words On Bathroom Walls
# 48     s77  Movie  Wonderful Nursery Rhymes with Mia - Little Bab...
# 49     s78  Movie  Wonderful Nursery Rhymes with Jacus - By Littl...
#
#                        director  \
# 0                  Don McKellar
# 1                  Girish Joshi
# 2                   Josh Webber
# 3                Sonia Anderson
# 4                  Giles Foster
# 5                  Paul Weiland
# 6                   Fran Strine
# 7   Thomas Kail, Alex Rudzinski
# 8                 Daniel Gilboy
# 9         Robert Allan Ackerman
# 10               Justin G. Dyck
# 11                 Liz Tuccillo
# 12             Dominique Rocher
# 13                Jep Barcelona
# 14               Sonia Anderson
# 15                Becca Gleason
# 16                 Glenn Miller
# 17                Drake Doremus
# 18                 William Nigh
# 19                Sam Pillsbury
# 20           Dr. Rudolf Lammers
# 21                   Ida Lupino
# 22                          NaN
# 23                          NaN
# 24              George C. Wolfe
# 25                Daisy Aitkens
# 26                  Mark Knight
# 27                  Mark Knight
# 28                  Mark Knight
# 29                  Mark Knight
# 30                  Mark Knight
# 31                  Mark Knight
# 32                  Mark Knight
# 33                  Mark Knight
# 34                  Mark Knight
# 35                  Mark Knight
# 36                  Mark Knight
# 37                  Mark Knight
# 38                  Mark Knight
# 39                 R. John Hugh
# 40                Mahi V Raghav
# 41                Mahi V Raghav
# 42                  Allan Moyle
# 43                Boaz Davidson
# 44              Jeffrey Schwarz
# 45                     Tim Gray
# 46                 Baeble Music
# 47             Thor Freudenthal
# 48                Cannis Holder
# 49                Cannis Holder
#
#                                                elenco            pais  \
# 0      Brendan Gleeson, Taylor Kitsch, Gordon Pinsent          Canada
# 1    Mahesh Manjrekar, Abhay Mahajan, Sachin Khedekar           India
# 2   Tom Sizemore, Lorenzo Lamas, Robert LaSardo, R...   United States
# 3   Interviews with: Pink, Adele, Beyoncé, Britney...   United States
# 4   Harry Dean Stanton, Kieran O'Brien, George Cos...  United Kingdom
# 5   Gregory Chisholm, Juliet Stevenson, Brian Hens...  United Kingdom
# 6   Alice Cooper, Liberty DeVitto, Ray Parker Jr.,...   United States
# 7   Julianne Hough, Aaron Tveit, Vanessa Hudgens, ...   United States
# 8   Michael Paré, Leanne Khol Young, Patrick J. Ma...          Canada
# 9     Kirstie Alley, Sam Waterston, Stockard Channing   United States
# 10  Emily Wilder, Adrian Cowan, Gary Mckenzie, Jer...          Canada
# 11            Leslie Bibb, Kevin Curtis, Nadia Dajani   United States
# 12  Anders Danielsen Lie, Golshifteh Farahani, Den...          France
# 13  Rafinha Alcantara, Marc-André Ter Stegen, Serg...           Spain
# 14  Elon Musk, Per Wimmer, Julie Anderson-Ankenbra...  United Kingdom
# 15  Joey King, Jack Kilmer, Andrea Savage, Paul Sc...   United States
# 16         Marcus Anderson, Kaiwi Lyman, Andrew Asper             NaN
# 17  Ewan McGregor, Léa Seydoux, Theo James, Mirand...             NaN
# 18                            Grace Hayes, Mary Healy             NaN
# 19  Nicolas Cage, Judge Reinhold, Erika Anderson, ...             NaN
# 20                                                NaN             NaN
# 21  Sally Forrest, Keefe Brasselle, Hugh O'Brian, ...             NaN
# 22                                                NaN             NaN
# 23                                                NaN             NaN
# 24            Hilary Swank, Emmy Rossum, Josh Duhamel             NaN
# 25  David Tennant, Lucy Punch, Faye Marsay, Gemma ...             NaN
# 26                                  Ann-Marie Newland             NaN
# 27                               Caroline Shola Arewa             NaN
# 28                                 Anne-Marie Newland             NaN
# 29                            Dr Daniel J Nightingale             NaN
# 30                                 Anne-Marie Newland             NaN
# 31                                 Anne-Marie Newland             NaN
# 32                                 Anne-Marie Newland             NaN
# 33                                 Anne-Marie Newland             NaN
# 34                                 Anne-Marie Newland             NaN
# 35                                 Anne-Marie Newland             NaN
# 36                                 Anne-Marie Newland             NaN
# 37                                 Anne-Marie Newland             NaN
# 38                                 Anne-Marie Newland             NaN
# 39  Lin McCarthy, Stephen Courtleigh, Berry Kroege...             NaN
# 40                     Mammootty, Suhasini Maniratnam             NaN
# 41                     Mammootty, Suhasini Maniratnam             NaN
# 42  Stephen Baldwin, Pascale Bussières, Kim Coates...             NaN
# 43                           Barbi Benton, Chip Lucia             NaN
# 44  Jack Wrangler, Margaret Whiting, Marc Shaiman,...             NaN
# 45                                        Dan Aykroyd             NaN
# 46                                                NaN             NaN
# 47  Charlie Plummer, Taylor Russell, Andy Garcia, ...             NaN
# 48                                                NaN             NaN
# 49                                                NaN             NaN
#
#     fecha_agregado  anio calificacion duracion  \
# 0   March 30, 2021  2014          NaN  113 min
# 1   March 30, 2021  2018          13+  110 min
# 2   March 30, 2021  2017          NaN   74 min
# 3   March 30, 2021  2014          NaN   69 min
# 4   March 30, 2021  1989          NaN   45 min
# 5   March 30, 2021  1989          NaN   52 min
# 6   March 30, 2021  2017          NaN   98 min
# 7   March 30, 2021  2016          NaN  131 min
# 8   March 30, 2021  2017          NaN   87 min
# 9    April 1, 2021  1994          NaN   92 min
# 10   April 4, 2021  2016          NaN   88 min
# 11  April 10, 2021  2014          NaN   93 min
# 12  April 17, 2021  2018          NaN   94 min
# 13  April 24, 2021  2020          NaN   46 min
# 14     May 2, 2021  2018          NaN   74 min
# 15    June 3, 2021  2019          NaN   96 min
# 16             NaN  2016          13+   87 min
# 17             NaN  2018            R  104 min
# 18             NaN  1941           NR   62 min
# 19             NaN  1991            R   94 min
# 20             NaN  2005          ALL   50 min
# 21             NaN  1949          18+   86 min
# 22             NaN  2007           NR   36 min
# 23             NaN  2007           NR   37 min
# 24             NaN  2015            R  103 min
# 25             NaN  2017          NaN   98 min
# 26             NaN  2016          ALL    9 min
# 27             NaN  2014          ALL   18 min
# 28             NaN  2016          ALL   14 min
# 29             NaN  2014          ALL   20 min
# 30             NaN  2014          ALL   19 min
# 31             NaN  2014          ALL   18 min
# 32             NaN  2014          ALL   20 min
# 33             NaN  2014          ALL   20 min
# 34             NaN  2016          ALL   22 min
# 35             NaN  2016          ALL   60 min
# 36             NaN  2016          ALL    6 min
# 37             NaN  2016          ALL   54 min
# 38             NaN  2019          ALL    5 min
# 39             NaN  1955          18+   84 min
# 40             NaN  2019          ALL  126 min
# 41             NaN  2019          ALL  125 min
# 42             NaN  2001            R  109 min
# 43             NaN  1983            R   89 min
# 44             NaN  2008          18+   85 min
# 45             NaN  2012          NaN   56 min
# 46             NaN  2007           NR   40 min
# 47             NaN  2020        PG-13  111 min
# 48             NaN  2019          ALL   33 min
# 49             NaN  2019          ALL   34 min
#
#                                          listado_en  \
# 0                                     Comedy, Drama
# 1                              Drama, International
# 2                           Action, Drama, Suspense
# 3                                       Documentary
# 4                                    Drama, Fantasy
# 5                                     Fantasy, Kids
# 6                     Documentary, Special Interest
# 7                                            Comedy
# 8                 Action, Science Fiction, Suspense
# 9                                             Drama
# 10                                  Adventure, Kids
# 11                                           Comedy
# 12                                 Horror, Suspense
# 13                              Documentary, Sports
# 14                                      Documentary
# 15                                    Comedy, Drama
# 16                          Horror, Science Fiction
# 17                                  Science Fiction
# 18  Arts, Entertainment, and Culture, Comedy, Drama
# 19                                            Drama
# 20                                      Documentary
# 21                                            Drama
# 22                        Music Videos and Concerts
# 23                        Music Videos and Concerts
# 24                                            Drama
# 25                                    Comedy, Drama
# 26                        Fitness, Special Interest
# 27         Faith and Spirituality, Special Interest
# 28                        Fitness, Special Interest
# 29                                 Special Interest
# 30                        Fitness, Special Interest
# 31                        Fitness, Special Interest
# 32                        Fitness, Special Interest
# 33                                 Special Interest
# 34                        Fitness, Special Interest
# 35                        Fitness, Special Interest
# 36                        Fitness, Special Interest
# 37                        Fitness, Special Interest
# 38                                 Special Interest
# 39                Action, Military and War, Western
# 40                             Drama, International
# 41                             Drama, International
# 42               Fantasy, Science Fiction, Suspense
# 43                                         Suspense
# 44                               Documentary, LGBTQ
# 45                                      Documentary
# 46                        Music Videos and Concerts
# 47                                            Drama
# 48                                             Kids
# 49                                             Kids
#
#                                           descripcion
# 0   A small fishing village must procure a local d...
# 1   A Metro Family decides to fight a Cyber Crimin...
# 2   After a man discovers his wife is cheating on ...
# 3   Pink breaks the mold once again, bringing her ...
# 4   Teenage Matt Banting wants to work with a famo...
# 5   The story unfolds in a an English seaside town...
# 6   They are the "First Call, A-list" musicians, j...
# 7   This honest, uncompromising comedy chronicles ...
# 8   A helicopter pilot and an environmental scient...
# 9   Sally Goodson is a devoted mother to her autis...
# 10  Amanda stumbles upon a hidden village of fairi...
# 11  When a car crash leaves Frannie immobilized, s...
# 12  After waking up in an apartment the night afte...
# 13  The documentary follows the midfielder’s every...
# 14  Discover the meteoric rise of Elon Musk, the m...
# 15  Summer '03 is the hilarious story of 16-year-o...
# 16  When a strange virus quickly spreads through a...
# 17  ZOE tells a tale of forbidden love between an ...
# 18  "Hey, kids, let's get together and put on a sh...
# 19  Zandalee has grown bored with her poet-turned-...
# 20  The Zambezi river is the fourth-longest river ...
# 21  Talented and beautiful Carol Williams (Forrest...
# 22  Young Love celebrates the release of "Too Youn...
# 23  Young Love returns to Baeble's silver screen w...
# 24  A drama centered on a classical pianist who ha...
# 25  In You, Me and Him we meet lesbian couple Oliv...
# 26  This session will establish how to prepare for...
# 27  Sharecare Windows presents Caroline Shola Arew...
# 28  Reduce the stress of flying by using these sim...
# 29  This session with Dr Daniel J Nightingale is h...
# 30  Relax and reduce your stress while you lay dow...
# 31  Yoga relaxation takes the whole body into a de...
# 32  This session was designed to help you relax an...
# 33  Relax and reduce your stress while you lay dow...
# 34  We take you through Buddhist mindful philosoph...
# 35  This session helps create confidence with simp...
# 36  This breathing practice will reduce stress, ca...
# 37  This session is about the key to yoga - synchr...
# 38  This breathing practice will reduce stress, ca...
# 39  During the U.S. Civil War, five deserters (yel...
# 40  An Indian politician takes up a decision to go...
# 41  An Indian politician takes up a decision to go...
# 42  A man learns the danger of a new technology th...
# 43  A psychotic killer keeps a young girl trapped ...
# 44  From the dawn of the sexual revolution comes t...
# 45  Over the course of five decades, Kenneth W. Re...
# 46  The circus comes to town with this performance...
# 47  Diagnosed with a mental illness, a witty, intr...
# 48  LittleBabyBum is proud to present a compilatio...
# 49  Enjoy this educational and fun compilation of ...

# %%
# Obtener los valores únicos en la columna
uniquegen1 = amazon['gen1'].unique()
print(uniquegen1)
# Out:
# ['Comedy' 'Drama' 'Action' 'Documentary' 'Fantasy' 'Adventure' 'Horror'
#  'Kids' 'Science Fiction' 'Arts' 'TV Shows' 'Animation' 'Anime'
#  'Music Videos and Concerts' 'Fitness' 'Faith and Spirituality'
#  'Special Interest' 'Suspense' 'Unscripted' 'Western' 'Arthouse' 'Sports'
#  'Military and War' 'International' 'Romance' 'Young Adult Audience'
#  'Talk Show and Variety' 'LGBTQ' 'Historical']

# %%
# Obtener los valores únicos en la columna
uniquegen2 = amazon['gen2'].unique()
print(uniquegen2)
# Out:
# [' Drama' ' International' None ' Fantasy' ' Kids' ' Special Interest'
#  ' Science Fiction' ' Suspense' ' Sports' ' Talk Show and Variety'
#  ' Anime' ' Entertainment' ' Adventure' ' Military and War' ' Western'
#  ' Animation' ' LGBTQ' ' Romance' ' Documentary' ' Faith and Spirituality'
#  ' Young Adult Audience' ' Comedy' ' Horror' ' Music Videos and Concerts'
#  ' Unscripted' ' Historical' ' Arts' ' Arthouse']

# %%
# Obtener los valores únicos en la columna
uniquegen3 = amazon['gen3'].unique()
print(uniquegen3)
# Out:
# [None ' Suspense' ' Comedy' ' and Culture' ' Fantasy' ' Animation'
#  ' Western' ' Kids' ' Unscripted' ' Sports' ' Special Interest' ' Drama'
#  ' International' ' Anime' ' LGBTQ' ' Romance' ' Young Adult Audience'
#  ' Horror' ' Science Fiction' ' Faith and Spirituality' ' Historical'
#  ' Military and War' ' Entertainment' ' Documentary'
#  ' Talk Show and Variety' ' Arts' ' Music Videos and Concerts']

# %%
# Obtener los valores únicos en la columna
uniquegen4 = amazon['gen4'].unique()
print(uniquegen4)
# Out:
# [None ' Comedy' ' Documentary' ' Drama' ' and Culture'
#  ' Music Videos and Concerts' ' Entertainment' ' International' ' Romance'
#  ' Horror' ' Fantasy' ' LGBTQ' ' Kids' ' Special Interest'
#  ' Young Adult Audience']

# %%
# Obtener los valores únicos en la columna
uniquegen5 = amazon['gen5'].unique()
print(uniquegen5)
# Out:
# [None ' Drama' ' Talk Show and Variety' ' Special Interest'
#  ' Music Videos and Concerts' ' Romance' ' Comedy' ' Documentary'
#  ' Military and War' ' Western' ' Kids' ' International' ' and Culture'
#  ' Unscripted' ' LGBTQ' ' Young Adult Audience' ' Science Fiction'
#  ' Suspense' ' Horror' ' Faith and Spirituality']
